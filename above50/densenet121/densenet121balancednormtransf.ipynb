tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(1960fb8a22eec11b:0:0), session_name()
# I0000 00:00:1730831074.597324     824 tpu_compile_op_common.cc:245] Compilation of 1960fb8a22eec11b:0:0 with session name  took 11.176200068s and succeeded
# I0000 00:00:1730831074.623607     824 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(1960fb8a22eec11b:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_663151253200474835", property.function_library_fingerprint = 9702044713093333220, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "2,224,224,3,;2,7,;2,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1730831074.623662     824 tpu_compilation_cache_interface.cc:541] After adding entry for key 1960fb8a22eec11b:0:0 with session_name  cache is 1 entries (37547939 bytes),  marked for eviction 0 entries (0 bytes).
# I0000 00:00:1730831099.732578     822 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(937cae60331fa434:0:0), session_name()
# I0000 00:00:1730831108.303382     822 tpu_compile_op_common.cc:245] Compilation of 937cae60331fa434:0:0 with session name  took 8.570744657s and succeeded
# I0000 00:00:1730831108.322801     822 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(937cae60331fa434:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_18399410500277218635", property.function_library_fingerprint = 2942310922376874855, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "2,224,224,3,;2,7,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1730831108.322837     822 tpu_compilation_cache_interface.cc:541] After adding entry for key 937cae60331fa434:0:0 with session_name  cache is 2 entries (74077530 bytes),  marked for eviction 0 entries (0 bytes).
# 654/654 - 57s - 87ms/step - accuracy: 0.1243 - auc: 0.7392 - false_negatives: 332.0000 - false_positives: 331.0000 - loss: 14.0688 - precision: 0.4931 - recall: 0.4924 - true_negatives: 3593.0000 - true_positives: 322.0000 - val_accuracy: 0.3754 - val_auc: 0.8002 - val_false_negatives: 32.0000 - val_false_positives: 32.0000 - val_loss: 12.6352 - val_precision: 0.6596 - val_recall: 0.6596 - val_true_negatives: 532.0000 - val_true_positives: 62.0000
# Epoch 2/10
# 654/654 - 21s - 32ms/step - accuracy: 0.2816 - auc: 0.8462 - false_negatives: 200.0000 - false_positives: 199.0000 - loss: 4.7769 - precision: 0.6953 - recall: 0.6942 - true_negatives: 3725.0000 - true_positives: 454.0000 - val_accuracy: 0.1565 - val_auc: 0.6907 - val_false_negatives: 54.0000 - val_false_positives: 54.0000 - val_loss: 22.2193 - val_precision: 0.4255 - val_recall: 0.4255 - val_true_negatives: 510.0000 - val_true_positives: 40.0000
# Epoch 3/10
# 654/654 - 21s - 32ms/step - accuracy: 0.4017 - auc: 0.8648 - false_negatives: 174.0000 - false_positives: 172.0000 - loss: 5.3142 - precision: 0.7362 - recall: 0.7339 - true_negatives: 3752.0000 - true_positives: 480.0000 - val_accuracy: 0.3997 - val_auc: 0.8270 - val_false_negatives: 32.0000 - val_false_positives: 32.0000 - val_loss: 8.3701 - val_precision: 0.6596 - val_recall: 0.6596 - val_true_negatives: 532.0000 - val_true_positives: 62.0000
# Epoch 4/10
# 654/654 - 21s - 32ms/step - accuracy: 0.4790 - auc: 0.8784 - false_negatives: 156.0000 - false_positives: 156.0000 - loss: 3.9413 - precision: 0.7615 - recall: 0.7615 - true_negatives: 3768.0000 - true_positives: 498.0000 - val_accuracy: 0.3435 - val_auc: 0.7330 - val_false_negatives: 47.0000 - val_false_positives: 47.0000 - val_loss: 22.1552 - val_precision: 0.5000 - val_recall: 0.5000 - val_true_negatives: 517.0000 - val_true_positives: 47.0000
# Epoch 5/10
# 654/654 - 21s - 32ms/step - accuracy: 0.5631 - auc: 0.9149 - false_negatives: 108.0000 - false_positives: 108.0000 - loss: 2.2783 - precision: 0.8349 - recall: 0.8349 - true_negatives: 3816.0000 - true_positives: 546.0000 - val_accuracy: 0.5745 - val_auc: 0.8754 - val_false_negatives: 22.0000 - val_false_positives: 22.0000 - val_loss: 7.7515 - val_precision: 0.7660 - val_recall: 0.7660 - val_true_negatives: 542.0000 - val_true_positives: 72.0000
# Epoch 6/10
# 654/654 - 21s - 32ms/step - accuracy: 0.6446 - auc: 0.9063 - false_negatives: 120.0000 - false_positives: 120.0000 - loss: 3.1273 - precision: 0.8165 - recall: 0.8165 - true_negatives: 3804.0000 - true_positives: 534.0000 - val_accuracy: 0.6413 - val_auc: 0.8328 - val_false_negatives: 27.0000 - val_false_positives: 27.0000 - val_loss: 13.3205 - val_precision: 0.7128 - val_recall: 0.7128 - val_true_negatives: 537.0000 - val_true_positives: 67.0000
# Epoch 7/10
# 654/654 - 21s - 32ms/step - accuracy: 0.6356 - auc: 0.9241 - false_negatives: 104.0000 - false_positives: 103.0000 - loss: 1.7998 - precision: 0.8423 - recall: 0.8410 - true_negatives: 3821.0000 - true_positives: 550.0000 - val_accuracy: 0.5881 - val_auc: 0.8431 - val_false_negatives: 27.0000 - val_false_positives: 27.0000 - val_loss: 11.7165 - val_precision: 0.7128 - val_recall: 0.7128 - val_true_negatives: 537.0000 - val_true_positives: 67.0000
# Epoch 8/10
# 654/654 - 21s - 32ms/step - accuracy: 0.6571 - auc: 0.9234 - false_negatives: 104.0000 - false_positives: 104.0000 - loss: 2.5657 - precision: 0.8410 - recall: 0.8410 - true_negatives: 3820.0000 - true_positives: 550.0000 - val_accuracy: 0.6109 - val_auc: 0.8246 - val_false_negatives: 29.0000 - val_false_positives: 29.0000 - val_loss: 13.1714 - val_precision: 0.6915 - val_recall: 0.6915 - val_true_negatives: 535.0000 - val_true_positives: 65.0000
# Epoch 9/10
# 654/654 - 22s - 33ms/step - accuracy: 0.7049 - auc: 0.9098 - false_negatives: 117.0000 - false_positives: 117.0000 - loss: 2.9378 - precision: 0.8211 - recall: 0.8211 - true_negatives: 3807.0000 - true_positives: 537.0000 - val_accuracy: 0.6322 - val_auc: 0.7851 - val_false_negatives: 36.0000 - val_false_positives: 36.0000 - val_loss: 19.8144 - val_precision: 0.6170 - val_recall: 0.6170 - val_true_negatives: 528.0000 - val_true_positives: 58.0000
# Epoch 10/10
# 654/654 - 21s - 32ms/step - accuracy: 0.7418 - auc: 0.9261 - false_negatives: 100.0000 - false_positives: 99.0000 - loss: 3.8531 - precision: 0.8484 - recall: 0.8471 - true_negatives: 3825.0000 - true_positives: 554.0000 - val_accuracy: 0.7340 - val_auc: 0.8857 - val_false_negatives: 22.0000 - val_false_positives: 22.0000 - val_loss: 12.0923 - val_precision: 0.7660 - val_recall: 0.7660 - val_true_negatives: 542.0000 - val_true_positives: 72.0000

# %%
del XTrain, YTrain
gc.collect()
# Out:
# 24296

# %%
YPredicted = model.predict(XTest)
print('Test set evaluation: ', model.evaluate(XTest, YTest, verbose = 0))
print('Validation set evaluation: ', model.evaluate(XVal, YVal, verbose = 0))
# Out:
# 2024-11-05 18:28:27.469080: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node functional_1/bn_1/Cast/ReadVariableOp.
# I0000 00:00:1730831308.235870     824 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(7f97ac2c03d2b466:0:0), session_name()
#  2/47 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step
# I0000 00:00:1730831317.724719     824 tpu_compile_op_common.cc:245] Compilation of 7f97ac2c03d2b466:0:0 with session name  took 9.488800868s and succeeded
# I0000 00:00:1730831317.743232     824 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(7f97ac2c03d2b466:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_15143678275459710912", property.function_library_fingerprint = 5347056539979822033, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1730831317.743270     824 tpu_compilation_cache_interface.cc:541] After adding entry for key 7f97ac2c03d2b466:0:0 with session_name  cache is 3 entries (109309655 bytes),  marked for eviction 0 entries (0 bytes).
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# I0000 00:00:1730831325.309562     805 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(df2db09468ccf63d:0:0), session_name()
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 31s 376ms/step
# I0000 00:00:1730831335.010447     805 tpu_compile_op_common.cc:245] Compilation of df2db09468ccf63d:0:0 with session name  took 9.700838029s and succeeded
# I0000 00:00:1730831335.029410     805 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(df2db09468ccf63d:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_6851659083102066687", property.function_library_fingerprint = 17911723910323384091, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "3,224,224,3,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1730831335.029456     805 tpu_compilation_cache_interface.cc:541] After adding entry for key df2db09468ccf63d:0:0 with session_name  cache is 4 entries (145079620 bytes),  marked for eviction 0 entries (0 bytes).
# I0000 00:00:1730831343.979226     805 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(6ab9b34fd6917dad:0:0), session_name()
# I0000 00:00:1730831367.438161     805 tpu_compile_op_common.cc:245] Compilation of 6ab9b34fd6917dad:0:0 with session name  took 23.458876932s and succeeded
# I0000 00:00:1730831367.457692     805 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(6ab9b34fd6917dad:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_18399410500277218635", property.function_library_fingerprint = 2942310922376874855, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "4,224,224,3,;4,7,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1730831367.457735     805 tpu_compilation_cache_interface.cc:541] After adding entry for key 6ab9b34fd6917dad:0:0 with session_name  cache is 5 entries (183134938 bytes),  marked for eviction 0 entries (0 bytes).
# I0000 00:00:1730831368.769039     835 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(a6c6ca7e4173dac5:0:0), session_name()
# I0000 00:00:1730831378.555355     835 tpu_compile_op_common.cc:245] Compilation of a6c6ca7e4173dac5:0:0 with session name  took 9.786268288s and succeeded
# I0000 00:00:1730831378.574879     835 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(a6c6ca7e4173dac5:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_18399410500277218635", property.function_library_fingerprint = 2942310922376874855, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "3,224,224,3,;3,7,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1730831378.574924     835 tpu_compilation_cache_interface.cc:541] After adding entry for key a6c6ca7e4173dac5:0:0 with session_name  cache is 6 entries (221506464 bytes),  marked for eviction 0 entries (0 bytes).
# Test set evaluation:  [10.485187530517578, 0.7402596473693848, 0.8795003294944763, 0.7754010558128357, 0.7754010558128357, 42.0, 42.0, 1080.0, 145.0]
# Validation set evaluation:  [14.187898635864258, 0.7097265124320984, 0.8545627593994141, 0.7234042286872864, 0.7234042286872864, 26.0, 26.0, 538.0, 68.0]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc = 'upper right')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc = 'upper right')
plt.show()

# %%
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc = 'upper right')
plt.show()

# %%
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc = 'upper right')
plt.show()

# %%
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc = 'upper right')
plt.show()

# %%
cm = confusion_matrix(YTest.argmax(axis = 1), YPredicted.argmax(axis = 1))

labels = ['Bowens disease',
          'Basal cell carcinoma',
          'Benign keratosis',
          'Dermatofibroma',
          'Vascular lesion',
          'Melanoma',
          'Melanocytic nevi']
dfCm = pd.DataFrame(cm, index = labels, columns = labels)

sns.set(font_scale = 1.4) # Label size
sns.heatmap(dfCm, annot = False, cmap = "Reds", annot_kws = {"size": 14}) # Font size

for i in range(totalClasses):
    for j in range(totalClasses):
        text = plt.text(j + 0.5, i + 0.5, f"{cm[i, j] / cm[i].sum() * 100:.2f}%", # {cm[i, j]:0d} ({cm[i, j] / cm[i].sum() * 100:.2f}%)
                        va = "center",
                        ha = "center",
                        color = "darkBlue",
                        fontsize = 10)

ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45, ha = 'right')

plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
del ax, cm, dfCm
gc.collect()
# Out:
# 34146

# %%
metrics = {
    'Precision': precision_score(YTest.argmax(axis=1), YPredicted.argmax(axis=1), average=None),
    'F1-score': f1_score(YTest.argmax(axis=1), YPredicted.argmax(axis=1), average=None),
    'ROC AUC': roc_auc_score(YTest, YPredicted, average=None),
    'Recall': recall_score(YTest.argmax(axis=1), YPredicted.argmax(axis=1), average=None)
}

cmMulti = multilabel_confusion_matrix(YTest.argmax(axis=1), YPredicted.argmax(axis=1))
specificity = []
for i in range(len(cmMulti)):
    tn = cmMulti[i][0][0]
    specificity.append(tn / (tn + cmMulti[i][0][1]))
metrics[f'Specificity'] = specificity

metrics[f'Confusion_Matrix'] = cmMulti
del cmMulti, specificity

# %%
for metric, values in metrics.items():
    print(metric + ':\n')
    if 'Confusion_Matrix' in metric:
        for id, value in enumerate(values):
          sns.set(font_scale = 1.4) # Label size
          percentages = value / np.sum(value, axis = 1, keepdims = True)
          sns.heatmap(value, annot = False, cmap = "Reds")
          ax = plt.gca()
          for i in range(len(value)):
              for j in range(len(value)):
                  ax.text(j + 0.5, i + 0.5, f'{percentages[i, j]*100:.0f}%', # {value[i, j]:0d} ({percentages[i, j]*100:.0f}%)
                          ha = 'center',
                          va = 'center',
                          color = 'darkBlue',
                          fontsize = 14)
          ax.set_yticklabels(['False', 'True'])
          ax.set_xticklabels(['False', 'True'])
          plt.title(f'{labels[id]}')
          plt.ylabel('True label')
          plt.xlabel('Predicted label')
          plt.show()
    else:
        for id, value in enumerate(values):
            df = pd.DataFrame({'Label': labels, 'Value': values})
        print(df.to_string(index = False, col_space = 10, justify = 'center'))
    print('\n')
# Out:
# Precision:
#
#        Label            Value
#       Bowens disease  0.590909
# Basal cell carcinoma  0.666667
#     Benign keratosis  0.399240
#       Dermatofibroma  0.666667
#      Vascular lesion  0.722222
#             Melanoma  0.350746
#     Melanocytic nevi  0.924774
#
#
# F1-score:
#
#        Label            Value
#       Bowens disease  0.382353
# Basal cell carcinoma  0.622951
#     Benign keratosis  0.514706
#       Dermatofibroma  0.222222
#      Vascular lesion  0.684211
#             Melanoma  0.365759
#     Melanocytic nevi  0.887819
#
#
# ROC AUC:
#
#        Label            Value
#       Bowens disease  0.907969
# Basal cell carcinoma  0.941950
#     Benign keratosis  0.887894
#       Dermatofibroma  0.623146
#      Vascular lesion  0.945268
#             Melanoma  0.867452
#     Melanocytic nevi  0.897447
#
#
# Recall:
#
#        Label            Value
#       Bowens disease  0.282609
# Basal cell carcinoma  0.584615
#     Benign keratosis  0.724138
#       Dermatofibroma  0.133333
#      Vascular lesion  0.650000
#             Melanoma  0.382114
#     Melanocytic nevi  0.853704
#
#
# Specificity:
#
#        Label            Value
#       Bowens disease  0.993785
# Basal cell carcinoma  0.986704
#     Benign keratosis  0.882876
#       Dermatofibroma  0.999324
#      Vascular lesion  0.996608
#             Melanoma  0.936543
#     Melanocytic nevi  0.818841
#
#
# Confusion_Matrix:

# %%
model.save(''.join([savePath, saveName, '.h5']))
if minMaxScalerNorm:
    joblib.dump(minMaxScaler, ''.join([savePath, saveName, 'MMscaler.pkl']))
elif standardScalerNorm:
    joblib.dump(standardScaler, ''.join([savePath, saveName, 'StdScaler.pkl']))
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 model.save(''.join([savePath, saveName, '.h5']))
#       2 if minMaxScalerNorm:
#       3     joblib.dump(minMaxScaler, ''.join([savePath, saveName, 'MMscaler.pkl']))
#
# File /usr/local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /usr/local/lib/python3.10/site-packages/tensorflow/python/distribute/packed_distributed_variable.py:91, in PackedDistributedVariable.get_var_on_device(self, device)
#      89   if d == device:
#      90     return self._distributed_variables[i]
# ---> 91 raise ValueError("Device %s is not found" % device)
#
# ValueError: Device /job:localhost/replica:0/task:0/device:CPU:0 is not found
