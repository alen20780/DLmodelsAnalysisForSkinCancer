property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "2,224,224,3,;2,7,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1731054161.275785     801 tpu_compilation_cache_interface.cc:541] After adding entry for key 3e15e639ecb76996:0:0 with session_name  cache is 1 entries (21634737 bytes),  marked for eviction 0 entries (0 bytes).
# 2024-11-08 08:23:44.687048: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Add/ReadVariableOp.
# I0000 00:00:1731054225.386634     769 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(ce7af1a05499b51f:0:0), session_name()
# I0000 00:00:1731054231.695331     769 tpu_compile_op_common.cc:245] Compilation of ce7af1a05499b51f:0:0 with session name  took 6.308632446s and succeeded
# I0000 00:00:1731054231.705046     769 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(ce7af1a05499b51f:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_11722916791829871709", property.function_library_fingerprint = 10452206357401518353, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "2,224,224,3,;2,7,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1731054231.705076     769 tpu_compilation_cache_interface.cc:541] After adding entry for key ce7af1a05499b51f:0:0 with session_name  cache is 2 entries (42290188 bytes),  marked for eviction 0 entries (0 bytes).
# 3339/3339 - 85s - 25ms/step - accuracy: 0.5591 - auc: 0.8449 - false_negatives: 999.0000 - false_positives: 995.0000 - loss: 10.0014 - precision: 0.7016 - recall: 0.7008 - true_negatives: 19039.0000 - true_positives: 2340.0000 - val_accuracy: 0.8480 - val_auc: 0.8941 - val_false_negatives: 18.0000 - val_false_positives: 18.0000 - val_loss: 8.8925 - val_precision: 0.8085 - val_recall: 0.8085 - val_true_negatives: 546.0000 - val_true_positives: 76.0000
# Epoch 2/10
# 3339/3339 - 62s - 19ms/step - accuracy: 0.7683 - auc: 0.9210 - false_negatives: 527.0000 - false_positives: 527.0000 - loss: 5.4260 - precision: 0.8422 - recall: 0.8422 - true_negatives: 19507.0000 - true_positives: 2812.0000 - val_accuracy: 0.8055 - val_auc: 0.9001 - val_false_negatives: 16.0000 - val_false_positives: 16.0000 - val_loss: 11.3955 - val_precision: 0.8298 - val_recall: 0.8298 - val_true_negatives: 548.0000 - val_true_positives: 78.0000
# Epoch 3/10
# 3339/3339 - 63s - 19ms/step - accuracy: 0.8469 - auc: 0.9415 - false_negatives: 371.0000 - false_positives: 371.0000 - loss: 4.0831 - precision: 0.8889 - recall: 0.8889 - true_negatives: 19663.0000 - true_positives: 2968.0000 - val_accuracy: 0.9043 - val_auc: 0.9069 - val_false_negatives: 15.0000 - val_false_positives: 15.0000 - val_loss: 12.7093 - val_precision: 0.8404 - val_recall: 0.8404 - val_true_negatives: 549.0000 - val_true_positives: 79.0000
# Epoch 4/10
# 3339/3339 - 63s - 19ms/step - accuracy: 0.8844 - auc: 0.9582 - false_negatives: 280.0000 - false_positives: 279.0000 - loss: 3.0284 - precision: 0.9164 - recall: 0.9161 - true_negatives: 19755.0000 - true_positives: 3059.0000 - val_accuracy: 0.9149 - val_auc: 0.9128 - val_false_negatives: 15.0000 - val_false_positives: 15.0000 - val_loss: 12.4950 - val_precision: 0.8404 - val_recall: 0.8404 - val_true_negatives: 549.0000 - val_true_positives: 79.0000
# Epoch 5/10
# 3339/3339 - 62s - 19ms/step - accuracy: 0.9074 - auc: 0.9664 - false_negatives: 224.0000 - false_positives: 224.0000 - loss: 2.3413 - precision: 0.9329 - recall: 0.9329 - true_negatives: 19810.0000 - true_positives: 3115.0000 - val_accuracy: 0.8982 - val_auc: 0.9131 - val_false_negatives: 14.0000 - val_false_positives: 14.0000 - val_loss: 16.6768 - val_precision: 0.8511 - val_recall: 0.8511 - val_true_negatives: 550.0000 - val_true_positives: 80.0000
# Epoch 6/10
# 3339/3339 - 63s - 19ms/step - accuracy: 0.9250 - auc: 0.9730 - false_negatives: 176.0000 - false_positives: 176.0000 - loss: 1.8315 - precision: 0.9473 - recall: 0.9473 - true_negatives: 19858.0000 - true_positives: 3163.0000 - val_accuracy: 0.9119 - val_auc: 0.9253 - val_false_negatives: 13.0000 - val_false_positives: 13.0000 - val_loss: 14.0048 - val_precision: 0.8617 - val_recall: 0.8617 - val_true_negatives: 551.0000 - val_true_positives: 81.0000
# Epoch 7/10
# 3339/3339 - 63s - 19ms/step - accuracy: 0.9387 - auc: 0.9775 - false_negatives: 147.0000 - false_positives: 147.0000 - loss: 1.7205 - precision: 0.9560 - recall: 0.9560 - true_negatives: 19887.0000 - true_positives: 3192.0000 - val_accuracy: 0.9347 - val_auc: 0.9315 - val_false_negatives: 11.0000 - val_false_positives: 11.0000 - val_loss: 13.1804 - val_precision: 0.8830 - val_recall: 0.8830 - val_true_negatives: 553.0000 - val_true_positives: 83.0000
# Epoch 8/10
# 3339/3339 - 63s - 19ms/step - accuracy: 0.9419 - auc: 0.9737 - false_negatives: 169.0000 - false_positives: 169.0000 - loss: 2.0652 - precision: 0.9494 - recall: 0.9494 - true_negatives: 19865.0000 - true_positives: 3170.0000 - val_accuracy: 0.9271 - val_auc: 0.8942 - val_false_negatives: 18.0000 - val_false_positives: 18.0000 - val_loss: 29.7604 - val_precision: 0.8085 - val_recall: 0.8085 - val_true_negatives: 546.0000 - val_true_positives: 76.0000
# Epoch 9/10
# 3339/3339 - 63s - 19ms/step - accuracy: 0.9548 - auc: 0.9829 - false_negatives: 109.0000 - false_positives: 109.0000 - loss: 1.1641 - precision: 0.9674 - recall: 0.9674 - true_negatives: 19925.0000 - true_positives: 3230.0000 - val_accuracy: 0.9271 - val_auc: 0.9315 - val_false_negatives: 12.0000 - val_false_positives: 12.0000 - val_loss: 18.7540 - val_precision: 0.8723 - val_recall: 0.8723 - val_true_negatives: 552.0000 - val_true_positives: 82.0000
# Epoch 10/10
# 3339/3339 - 63s - 19ms/step - accuracy: 0.9603 - auc: 0.9844 - false_negatives: 99.0000 - false_positives: 99.0000 - loss: 1.1823 - precision: 0.9704 - recall: 0.9704 - true_negatives: 19935.0000 - true_positives: 3240.0000 - val_accuracy: 0.9529 - val_auc: 0.9255 - val_false_negatives: 12.0000 - val_false_positives: 12.0000 - val_loss: 23.2297 - val_precision: 0.8723 - val_recall: 0.8723 - val_true_negatives: 552.0000 - val_true_positives: 82.0000

# %%
del XTrain, YTrain
gc.collect()
# Out:
# 12601

# %%
YPredicted = model.predict(XTest)
print('Test set evaluation: ', model.evaluate(XTest, YTest, verbose = 0))
print('Validation set evaluation: ', model.evaluate(XVal, YVal, verbose = 0))
# Out:
# 2024-11-08 08:33:24.289301: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node functional_1/conv1_bn_1/Cast/ReadVariableOp.
# I0000 00:00:1731054804.679109     818 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(469b9b1731bd60a0:0:0), session_name()
#  3/47 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# I0000 00:00:1731054811.543799     818 tpu_compile_op_common.cc:245] Compilation of 469b9b1731bd60a0:0:0 with session name  took 6.864646935s and succeeded
# I0000 00:00:1731054811.553129     818 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(469b9b1731bd60a0:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_17081668352334118287", property.function_library_fingerprint = 4788722551070645916, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1731054811.553159     818 tpu_compilation_cache_interface.cc:541] After adding entry for key 469b9b1731bd60a0:0:0 with session_name  cache is 3 entries (59652487 bytes),  marked for eviction 0 entries (0 bytes).
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# I0000 00:00:1731054816.758237     804 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(4c42d9aa914799b5:0:0), session_name()
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 290ms/step
# I0000 00:00:1731054824.875314     804 tpu_compile_op_common.cc:245] Compilation of 4c42d9aa914799b5:0:0 with session name  took 8.117037789s and succeeded
# I0000 00:00:1731054824.886884     804 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(4c42d9aa914799b5:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_37810405873264970", property.function_library_fingerprint = 1711576973501823304, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "3,224,224,3,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1731054824.886915     804 tpu_compilation_cache_interface.cc:541] After adding entry for key 4c42d9aa914799b5:0:0 with session_name  cache is 4 entries (77991893 bytes),  marked for eviction 0 entries (0 bytes).
# I0000 00:00:1731054831.714245     810 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(e2b7c4b23348632a:0:0), session_name()
# I0000 00:00:1731054839.233621     810 tpu_compile_op_common.cc:245] Compilation of e2b7c4b23348632a:0:0 with session name  took 7.51932324s and succeeded
# I0000 00:00:1731054839.246805     810 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(e2b7c4b23348632a:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_11722916791829871709", property.function_library_fingerprint = 10452206357401518353, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "4,224,224,3,;4,7,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1731054839.246850     810 tpu_compilation_cache_interface.cc:541] After adding entry for key e2b7c4b23348632a:0:0 with session_name  cache is 5 entries (98072087 bytes),  marked for eviction 0 entries (0 bytes).
# I0000 00:00:1731054840.214394     760 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(712a5feb209e6207:0:0), session_name()
# I0000 00:00:1731054848.569618     760 tpu_compile_op_common.cc:245] Compilation of 712a5feb209e6207:0:0 with session name  took 8.355185445s and succeeded
# I0000 00:00:1731054848.581024     760 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(712a5feb209e6207:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_11722916791829871709", property.function_library_fingerprint = 10452206357401518353, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "3,224,224,3,;3,7,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1731054848.581054     760 tpu_compilation_cache_interface.cc:541] After adding entry for key 712a5feb209e6207:0:0 with session_name  cache is 6 entries (119058044 bytes),  marked for eviction 0 entries (0 bytes).
# Test set evaluation:  [36.31980895996094, 0.9152023196220398, 0.884399950504303, 0.7967914342880249, 0.7967914342880249, 38.0, 38.0, 1084.0, 149.0]
# Validation set evaluation:  [29.64980697631836, 0.9209727048873901, 0.9066131114959717, 0.8297872543334961, 0.8297872543334961, 16.0, 16.0, 548.0, 78.0]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc = 'upper right')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc = 'upper right')
plt.show()

# %%
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc = 'upper right')
plt.show()

# %%
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc = 'upper right')
plt.show()

# %%
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc = 'upper right')
plt.show()

# %%
cm = confusion_matrix(YTest.argmax(axis = 1), YPredicted.argmax(axis = 1))

labels = ['Bowens disease',
          'Basal cell carcinoma',
          'Benign keratosis',
          'Dermatofibroma',
          'Vascular lesion',
          'Melanoma',
          'Melanocytic nevi']
dfCm = pd.DataFrame(cm, index = labels, columns = labels)

sns.set(font_scale = 1.4) # Label size
sns.heatmap(dfCm, annot = False, cmap = "Reds", annot_kws = {"size": 14}) # Font size

for i in range(totalClasses):
    for j in range(totalClasses):
        text = plt.text(j + 0.5, i + 0.5, f"{cm[i, j] / cm[i].sum() * 100:.2f}%", # {cm[i, j]:0d} ({cm[i, j] / cm[i].sum() * 100:.2f}%)
                        va = "center",
                        ha = "center",
                        color = "darkBlue",
                        fontsize = 10)

ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45, ha = 'right')

plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
del ax, cm, dfCm
gc.collect()
# Out:
# 34967

# %%
metrics = {
    'Precision': precision_score(YTest.argmax(axis=1), YPredicted.argmax(axis=1), average=None),
    'F1-score': f1_score(YTest.argmax(axis=1), YPredicted.argmax(axis=1), average=None),
    'ROC AUC': roc_auc_score(YTest, YPredicted, average=None),
    'Recall': recall_score(YTest.argmax(axis=1), YPredicted.argmax(axis=1), average=None)
}

cmMulti = multilabel_confusion_matrix(YTest.argmax(axis=1), YPredicted.argmax(axis=1))
specificity = []
for i in range(len(cmMulti)):
    tn = cmMulti[i][0][0]
    specificity.append(tn / (tn + cmMulti[i][0][1]))
metrics[f'Specificity'] = specificity

metrics[f'Confusion_Matrix'] = cmMulti
del cmMulti, specificity

# %%
for metric, values in metrics.items():
    print(metric + ':\n')
    if 'Confusion_Matrix' in metric:
        for id, value in enumerate(values):
          sns.set(font_scale = 1.4) # Label size
          percentages = value / np.sum(value, axis = 1, keepdims = True)
          sns.heatmap(value, annot = False, cmap = "Reds")
          ax = plt.gca()
          for i in range(len(value)):
              for j in range(len(value)):
                  ax.text(j + 0.5, i + 0.5, f'{percentages[i, j]*100:.0f}%', # {value[i, j]:0d} ({percentages[i, j]*100:.0f}%)
                          ha = 'center',
                          va = 'center',
                          color = 'darkBlue',
                          fontsize = 14)
          ax.set_yticklabels(['False', 'True'])
          ax.set_xticklabels(['False', 'True'])
          plt.title(f'{labels[id]}')
          plt.ylabel('True label')
          plt.xlabel('Predicted label')
          plt.show()
    else:
        for id, value in enumerate(values):
            df = pd.DataFrame({'Label': labels, 'Value': values})
        print(df.to_string(index = False, col_space = 10, justify = 'center'))
    print('\n')
# Out:
# Precision:
#
#        Label            Value
#       Bowens disease  0.548387
# Basal cell carcinoma  0.481481
#     Benign keratosis  0.548148
#       Dermatofibroma  0.666667
#      Vascular lesion  0.588235
#             Melanoma  0.519231
#     Melanocytic nevi  0.852377
#
#
# F1-score:
#
#        Label            Value
#       Bowens disease  0.441558
# Basal cell carcinoma  0.436975
#     Benign keratosis  0.528571
#       Dermatofibroma  0.380952
#      Vascular lesion  0.540541
#             Melanoma  0.308571
#     Melanocytic nevi  0.896885
#
#
# ROC AUC:
#
#        Label            Value
#       Bowens disease  0.769067
# Basal cell carcinoma  0.790730
#     Benign keratosis  0.787426
#       Dermatofibroma  0.631373
#      Vascular lesion  0.771896
#             Melanoma  0.672914
#     Melanocytic nevi  0.777876
#
#
# Recall:
#
#        Label            Value
#       Bowens disease  0.369565
# Basal cell carcinoma  0.400000
#     Benign keratosis  0.510345
#       Dermatofibroma  0.266667
#      Vascular lesion  0.500000
#             Melanoma  0.219512
#     Melanocytic nevi  0.946296
#
#
# Specificity:
#
#        Label            Value
#       Bowens disease  0.990331
# Basal cell carcinoma  0.980406
#     Benign keratosis  0.954781
#       Dermatofibroma  0.998648
#      Vascular lesion  0.995251
#             Melanoma  0.981765
#     Melanocytic nevi  0.572464
#
#
# Confusion_Matrix:

# %%
model.save(''.join([savePath, saveName, '.h5']))
if minMaxScalerNorm:
    joblib.dump(minMaxScaler, ''.join([savePath, saveName, 'MMscaler.pkl']))
elif standardScalerNorm:
    joblib.dump(standardScaler, ''.join([savePath, saveName, 'StdScaler.pkl']))
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 model.save(''.join([savePath, saveName, '.h5']))
#       2 if minMaxScalerNorm:
#       3     joblib.dump(minMaxScaler, ''.join([savePath, saveName, 'MMscaler.pkl']))
#
# File /usr/local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /usr/local/lib/python3.10/site-packages/tensorflow/python/distribute/packed_distributed_variable.py:91, in PackedDistributedVariable.get_var_on_device(self, device)
#      89   if d == device:
#      90     return self._distributed_variables[i]
# ---> 91 raise ValueError("Device %s is not found" % device)
#
# ValueError: Device /job:localhost/replica:0/task:0/device:CPU:0 is not found
